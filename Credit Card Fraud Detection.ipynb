# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('creditcard.csv')
# Out:
# <ipython-input-2-52bf31760f11>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   credit_card_data = pd.read_csv('creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 286781  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 286782  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 286783  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 286784  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 286785  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 286781 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 286782  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 286783  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 286784  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 286785 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286786 entries, 0 to 286785
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    286786 non-null  float64
#  1   V1      286786 non-null  float64
#  2   V2      286786 non-null  float64
#  3   V3      286786 non-null  float64
#  4   V4      286786 non-null  float64
#  5   V5      286786 non-null  float64
#  6   V6      286786 non-null  float64
#  7   V7      286786 non-null  float64
#  8   V8      286786 non-null  float64
#  9   V9      286786 non-null  float64
#  10  V10     286786 non-null  float64
#  11  V11     286786 non-null  float64
#  12  V12     286786 non-null  float64
#  13  V13     286786 non-null  float64
#  14  V14     286786 non-null  float64
#  15  V15     286786 non-null  float64
#  16  V16     286786 non-null  float64
#  17  V17     286786 non-null  float64
#  18  V18     286786 non-null  float64
#  19  V19     286786 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    286292
# 1       494
# Name: count, dtype: int64

# %% [markdown]
# 0 -> This indicates normal transaction
# 1 -> This indicates fraudulent transaction

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (286292, 31)
# (494, 31)

# %%
legit.Amount.describe()
# Out:
# count    286292.000000
# mean         88.140166
# std         249.539578
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.000000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     494.000000
# mean      122.291296
# std       256.239574
# min         0.000000
# 25%         1.000000
# 50%         9.555000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Assuming `credit_card_data` is your DataFrame

# Select only numeric columns
numeric_columns = credit_card_data.select_dtypes(include='number')

# Group by 'Class' and compute the mean
mean_values = numeric_columns.groupby(credit_card_data['Class']).mean()

print(mean_values)
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94683.699796  0.006844 -0.004573  0.016578 -0.006799  0.003685
# 1      80713.724696 -4.763378  3.608978 -7.008181  4.533910 -3.141387
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002434  0.008941 -0.000201  0.002590  ... -0.000415 -0.001839
# 1     -1.393828 -5.554685  0.570508 -2.573052  ...  0.371809  0.714068
#
#             V22       V24       V25       V26       V27       V28      Amount  \
# Class
# 0     -0.001247  0.000305  0.000768  0.000276 -0.000415 -0.000105   88.140166
# 1      0.015500 -0.104631  0.039772  0.050564  0.172468  0.074369  122.291296
#
#        Class
# Class
# 0        0.0
# 1        1.0
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 113086   72093.0  1.152895  0.422838  1.058124  2.513418 -0.511189 -0.298946
# 142423   83722.0 -1.376245  0.899477  1.620318  0.297977  0.193500 -0.116760
# 265348  160923.0  2.060703 -0.111969 -1.078747  0.426953 -0.224233 -1.239221
# 255445  156265.0  2.017953  0.058252 -1.619452  0.353067  0.315459 -0.681202
# 237239  148320.0 -0.849464  0.884699 -0.169456 -0.501700  0.336282 -1.149958
#
#               V7        V8        V9  ...       V21       V22  \
# 113086 -0.226398 -0.003004 -0.440348  ...  0.143071  0.385960
# 142423  0.258325  0.713065 -0.665712  ...  0.062016  0.020455
# 265348  0.127565 -0.287425  0.669409  ... -0.298327 -0.767055
# 255445  0.036451 -0.059286  0.334024  ... -0.309022 -0.858695
# 237239  0.760362  0.170260 -0.175649  ... -0.093609 -0.205548
#
#                        V23       V24       V25       V26       V27       V28  \
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 281842  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 282122  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 282128  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 283123  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 283653  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 281842 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 282122 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234  -0.14564
# 282128 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 283123 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 283653  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 1    494
# 0    492
# Name: count, dtype: int64

# %%
# Select only numeric columns
numeric_columns = new_dataset.select_dtypes(include='number')

# Group by 'Class' and compute the mean
mean_values = numeric_columns.groupby(new_dataset['Class']).mean()

print(mean_values)
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97209.441057 -0.047046  0.071613 -0.034715  0.014508  0.079495
# 1      80713.724696 -4.763378  3.608978 -7.008181  4.533910 -3.141387
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.117456  0.049803 -0.062327 -0.017972  ... -0.048755  0.027570
# 1     -1.393828 -5.554685  0.570508 -2.573052  ...  0.371809  0.714068
#
#             V22       V24       V25       V26       V27       V28      Amount  \
# Class
# 0     -0.067073  0.014338  0.013605 -0.019596 -0.008400 -0.007135   88.848902
# 1      0.015500 -0.104631  0.039772  0.050564  0.172468  0.074369  122.291296
#
#        Class
# Class
# 0        0.0
# 1        1.0
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 113086   72093.0  1.152895  0.422838  1.058124  2.513418 -0.511189 -0.298946
# 142423   83722.0 -1.376245  0.899477  1.620318  0.297977  0.193500 -0.116760
# 265348  160923.0  2.060703 -0.111969 -1.078747  0.426953 -0.224233 -1.239221
# 255445  156265.0  2.017953  0.058252 -1.619452  0.353067  0.315459 -0.681202
# 237239  148320.0 -0.849464  0.884699 -0.169456 -0.501700  0.336282 -1.149958
# ...          ...       ...       ...       ...       ...       ...       ...
# 281842  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 282122  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 282128  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 283123  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 283653  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 113086    0
# 142423    0
# 265348    0
# 255445    0
# 237239    0
#          ..
# 281842    1
# 282122    1
# 282128    1
# 283123    1
# 283653    1
# Name: Class, Length: 986, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (986, 30) (788, 30) (198, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9238578680203046

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.8888888888888888
